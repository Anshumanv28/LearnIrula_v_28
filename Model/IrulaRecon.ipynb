# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/My\ Drive/Colab_Notebooks/
# Out:
# augmentor.py  downloader.py	__pycache__	  testeraudio.py	 trained_model
# converter.py  IrulaRecon.ipynb	requirements.txt  tester.py		 trained_siamese_model.pth
# data	      main.py		siamese_train.py  test_set_generator.py

# %%
# !pip install -r /content/drive/My\ Drive/Colab_Notebooks/requirements.txt
# Out:
# ...
# INFO: pip is looking at multiple versions of multiprocess to determine which version is compatible with other requirements. This could take a while.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab_Notebooks'

# %%
ls
# Out:
# augmentor.py  downloader.py     __pycache__/       siamese_train.py  test_set_generator.py
# converter.py  IrulaRecon.ipynb  requirements.txt   testeraudio.py    trained_model/
# data/         main.py           siamese_tester.py  tester.py         trained_siamese_model.pth

# %%
cd ./drive/My\ Drive/Colab_Notebooks/
# Out:
# /content/drive/My Drive/Colab_Notebooks

# %%
# !python /content/drive/My\ Drive/Colab_Notebooks/downloader.py

# %%
# !ls /content/drive/My\ Drive/Colab_Notebooks/data/downloaded_audio/
# Out:
# Across.mp3  Blue.mp3	 Cloud.mp3	Dilute.mp3	Erase.mp3	Green.mp3    Mouth.mp3
# Act.mp3     Bone.mp3	 Cockroach.mp3	Do.mp3		Extinguish.mp3	Hair.mp3     Nose.mp3
# Anklet.mp3  Bow.mp3	 Coffee.mp3	Downwards.mp3	Far.mp3		Head.mp3     Out.mp3
# Arm.mp3     Boy.mp3	 Cold.mp3	Draw.mp3	Fire.mp3	Hen.mp3      Pain.mp3
# Ash.mp3     Brother.mp3  Cow.mp3	Ears.mp3	Flood.mp3	Honey.mp3    Pebble.mp3
# Baby.mp3    Buffalo.mp3  Crow.mp3	Earthquake.mp3	Fly.mp3		Ice.mp3
# Bend.mp3    Butter.mp3	 Darkness.mp3	East.mp3	Food.mp3	Kitchen.mp3
# Bind.mp3    Catch.mp3	 Demolish.mp3	Ember.mp3	Fuel.mp3	Milk.mp3
# Blow.mp3    Cat.mp3	 Destroy.mp3	Empty.mp3	Gather.mp3	Moth.mp3

# %%
# !python /content/drive/My\ Drive/Colab_Notebooks/converter.py

# %%
# !ls /content/drive/My\ Drive/Colab_Notebooks/data/converted_audio/
# Out:
# Across.wav  Blue.wav	 Cloud.wav	Dilute.wav	Erase.wav	Green.wav    Mouth.wav
# Act.wav     Bone.wav	 Cockroach.wav	Do.wav		Extinguish.wav	Hair.wav     Nose.wav
# Anklet.wav  Bow.wav	 Coffee.wav	Downwards.wav	Far.wav		Head.wav     Out.wav
# Arm.wav     Boy.wav	 Cold.wav	Draw.wav	Fire.wav	Hen.wav      Pain.wav
# Ash.wav     Brother.wav  Cow.wav	Ears.wav	Flood.wav	Honey.wav    Pebble.wav
# Baby.wav    Buffalo.wav  Crow.wav	Earthquake.wav	Fly.wav		Ice.wav
# Bend.wav    Butter.wav	 Darkness.wav	East.wav	Food.wav	Kitchen.wav
# Bind.wav    Catch.wav	 Demolish.wav	Ember.wav	Fuel.wav	Milk.wav
# Blow.wav    Cat.wav	 Destroy.wav	Empty.wav	Gather.wav	Moth.wav

# %%
# !python /content/drive/My\ Drive/Colab_Notebooks/augmentor.py

# %%
# !ls /content/drive/My\ Drive/Colab_Notebooks/data/augmented_audio/

# %%
# !python siamese_train.py
# Out:
# /content/drive/MyDrive/Colab_Notebooks/siamese_train.py:305: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()  # Initialize the GradScaler for mixed precision
# /content/drive/MyDrive/Colab_Notebooks/siamese_train.py:317: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():  # Mixed precision context
# Epoch: 1, Training Loss: 0.6570225995668071
# Epoch: 1, Validation Loss: 1.0549080868562062
# Epoch: 2, Training Loss: 0.8402810480366362
# Epoch: 2, Validation Loss: 0.5691079081346592
# Epoch: 3, Training Loss: 0.6124130775557554
# Epoch: 3, Validation Loss: 0.48459221826245386
# Epoch: 4, Training Loss: 0.5282777838329685
# Epoch: 4, Validation Loss: 0.4663327928477277
# Epoch: 5, Training Loss: 0.5172104500927666
# Epoch: 5, Validation Loss: 0.46495945922409493

# %%
# !python test_set_generator.py
# Out:
# Selected test files: ['Food_stretched.wav', 'Blow_pitch_shifted_male.wav', 'Do_pitch_shifted_female.wav', 'Kitchen_original.wav', 'Bend_stretched.wav', 'Gather_original.wav', 'East_pitch_shifted_female.wav', 'Fuel_original.wav', 'Butter_noisy.wav', 'Cow_pitch_shifted_female.wav', 'Gather_louder.wav', 'Ears_quieter.wav', 'Fire_shifted.wav', 'Fire_pitch_shifted_male.wav', 'Empty_original.wav', 'Buffalo_shifted.wav', 'Far_shifted.wav', 'Anklet_quieter.wav', 'Head_noisy.wav', 'Pain_stretched.wav', 'Milk_noisy.wav', 'Buffalo_louder.wav', 'Hen_pitch_shifted_male.wav', 'Hen_louder.wav', 'Blue_pitch_shifted_male.wav', 'Cold_pitch_shifted_female.wav', 'Crow_quieter.wav', 'Anklet_louder.wav', 'Cockroach_shifted.wav', 'Erase_noisy.wav', 'Crow_stretched.wav', 'Ember_pitch_shifted_female.wav', 'Cat_quieter.wav', 'Hair_pitch_shifted_male.wav', 'Bend_noisy.wav', 'Nose_pitch_shifted_female.wav', 'Flood_stretched.wav', 'Extinguish_pitch_shifted_male.wav', 'Ash_louder.wav', 'Boy_shifted.wav', 'Destroy
# ...

# %%
# !python siamese_tester.py
# Out:
# /content/drive/My Drive/Colab_Notebooks/siamese_tester.py:286: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !python threshold_tuner.py
# Out:
# /content/drive/MyDrive/Colab_Notebooks/threshold_tuner.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !python main.py

# %%
#check model vocabulary

from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

model_path = './trained_model'  # Adjust to your saved model path
model = Wav2Vec2ForCTC.from_pretrained(model_path)
processor = Wav2Vec2Processor.from_pretrained(model_path)

print(processor.tokenizer.get_vocab())
# Out:
# {"'": 27, '</s>': 2, '<pad>': 0, '<s>': 1, '<unk>': 3, 'A': 7, 'B': 24, 'C': 19, 'D': 14, 'E': 5, 'F': 20, 'G': 21, 'H': 11, 'I': 10, 'J': 29, 'K': 26, 'L': 15, 'M': 17, 'N': 9, 'O': 8, 'P': 23, 'Q': 30, 'R': 13, 'S': 12, 'T': 6, 'U': 16, 'V': 25, 'W': 18, 'X': 28, 'Y': 22, 'Z': 31, '|': 4}

# %%
import torch
import torchaudio
import sounddevice as sd
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
import numpy as np

# Load the trained model and processor
model_path = './trained_model'  # Adjust to your saved model path
model = Wav2Vec2ForCTC.from_pretrained(model_path)
processor = Wav2Vec2Processor.from_pretrained(model_path)

# Set the model to evaluation mode
model.eval()

# Check if GPU is available and move model to GPU if so
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Function to record audio using the microphone
def record_audio(duration=5, fs=16000):
    print(f"Recording for {duration} seconds...")
    audio = sd.rec(int(duration * fs), samplerate=fs, channels=1, dtype='float32')
    sd.wait()  # Wait until recording is finished
    return np.squeeze(audio)

# Function to transcribe recorded audio
def transcribe_audio(audio):
    # Tokenize the audio (convert to input for model)
    inputs = processor(audio, sampling_rate=16000, return_tensors="pt", padding=True).to(device)

    # Run the model and get logits
    with torch.no_grad():
        logits = model(input_values=inputs.input_values).logits

    # Decode the logits to get the predicted text
    predicted_ids = torch.argmax(logits, dim=-1)
    transcription = processor.decode(predicted_ids[0])

    return transcription

# Record the audio from the microphone
audio_data = record_audio(duration=5, fs=16000)  # You can adjust the duration

# Test the model on the recorded audio
prediction = transcribe_audio(audio_data)

print(f"Predicted word: {prediction}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-48ef730b1138> in <cell line: 3>()
#       1 import torch
#       2 import torchaudio
# ----> 3 import sounddevice as sd
#       4 from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
#       5 import numpy as np
#
# /usr/local/lib/python3.10/dist-packages/sounddevice.py in <module>
#      69             break
#      70     else:
# ---> 71         raise OSError('PortAudio library not found')
#      72     _lib = _ffi.dlopen(_libname)
#      73 except OSError:
#
# OSError: PortAudio library not found
